# %% [markdown]
# <a href="https://colab.research.google.com/github/reshmachambhare/Youtube_review_sentiment_score_using_bert/blob/main/chapa_kata_trailer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import re
import numpy as np
import pandas as pd

# %% [markdown]
# ### dunki_comments from youtube

# %%
df_for_youtube = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/youtube_comments.csv')
df_for_youtube.head()
# Out:
#                  Name               Comment                  Time  Likes  \
# 0          @samat8157                     ❤  2023-12-12T09:11:41Z      0
# 1  @helpingbrains2941           Wahiyat SRK  2023-12-12T08:59:30Z      0
# 2     @b.kagrawal7969     Overacting of SRK  2023-12-12T08:54:03Z      1
# 3    @user-iq2jc3wi7h     Rajkumar hirani 💥  2023-12-12T08:53:49Z      0
# 4       @anishali2865  Dunki is best teller  2023-12-12T08:46:57Z      0
#
#    Reply Count
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df_for_youtube = df_for_youtube[['Comment']]

# %%
df_for_youtube.head()
# Out:
#                 Comment
# 0                     ❤
# 1           Wahiyat SRK
# 2     Overacting of SRK
# 3     Rajkumar hirani 💥
# 4  Dunki is best teller

# %%
# Instantiate Model

tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# %%
def sentiment_score(review):
  tokens = tokenizer.encode(review, return_tensors='pt')
  result = model(tokens)
  return int(torch.argmax(result.logits))+1

# %%
import pandas as pd

# Read the .pkl file into a Pandas DataFrame
df = pd.read_pickle('/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/df_for_youtube.pkl')

# Save the DataFrame to a CSV file
df.to_csv('/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/dunki_youtube_comments.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/dunki_youtube_comments.csv')
df.head()
# Out:
#                  Name               Comment                  Time  Likes  \
# 0          @samat8157                     ❤  2023-12-12T09:11:41Z    0.0
# 1  @helpingbrains2941           Wahiyat SRK  2023-12-12T08:59:30Z    0.0
# 2     @b.kagrawal7969     Overacting of SRK  2023-12-12T08:54:03Z    1.0
# 3    @user-iq2jc3wi7h     Rajkumar hirani 💥  2023-12-12T08:53:49Z    0.0
# 4       @anishali2865  Dunki is best teller  2023-12-12T08:46:57Z    0.0
#
#    Reply Count  sentiment score
# 0          0.0              5.0
# 1          0.0              1.0
# 2          0.0              2.0
# 3          0.0              4.0
# 4          0.0              5.0

# %% [markdown]
# ## For chapa_kata_trailer_comments from youtube

# %%
df_chapa_kata_trailer_comments = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/chapa_kata_trailer_comments.csv')
df_chapa_kata_trailer_comments.head()
# Out:
#                      Name                                            Comment  \
# 0       @sachinshinde4329         प्रदर्शित का नाही झाला वाट बघतोय राव आम्ही
# 1  @nirajgaikwadshortfilm  <a href="https://youtu.be/Bb_mEMJ6yec?si=bU73D...
# 2              @vindhende  khup divasanni makarand siranni movie aanaliy ...
# 3          @jelexjoseph23                                        Sad trailer
# 4         @sachinbhui2333  मराठीत विनोदी चित्रपट पेक्षा काही वेगळे प्रयत्...
#
#                    Time  Likes  Reply Count
# 0  2023-12-17T09:51:44Z      1            0
# 1  2023-12-15T18:55:58Z      0            0
# 2  2023-12-15T14:16:50Z      1            0
# 3  2023-12-15T10:18:58Z      1            0
# 4  2023-12-14T05:31:32Z      1            0

# %%
df_chapa_kata_trailer_comments = df_chapa_kata_trailer_comments[['Comment']]

# %%
df_chapa_kata_trailer_comments
# Out:
#                                               Comment
# 0          प्रदर्शित का नाही झाला वाट बघतोय राव आम्ही
# 1   <a href="https://youtu.be/Bb_mEMJ6yec?si=bU73D...
# 2   khup divasanni makarand siranni movie aanaliy ...
# 3                                         Sad trailer
# 4   मराठीत विनोदी चित्रपट पेक्षा काही वेगळे प्रयत्...
# ..                                                ...
# 57               after long time good movie is coming
# 58                           Kadak. 1st day 1st show.
# 59                          ALL THE BEST - TEAM ULTRA
# 60                                     movie to watch
# 61                                        👌🏻👌🏻👍🏻👍🏻👍🏻🤣
#
# [62 rows x 1 columns]

# %%
df_chapa_kata_trailer_comments['sentiment_score'] = df_chapa_kata_trailer_comments['Comment'].apply(lambda x:sentiment_score(x[:512])) # :512 use because only 512 token in a sentence can encode

# %%
df_chapa_kata_trailer_comments
# Out:
#                                               Comment  sentiment_score
# 0          प्रदर्शित का नाही झाला वाट बघतोय राव आम्ही                1
# 1   <a href="https://youtu.be/Bb_mEMJ6yec?si=bU73D...                3
# 2   khup divasanni makarand siranni movie aanaliy ...                3
# 3                                         Sad trailer                1
# 4   मराठीत विनोदी चित्रपट पेक्षा काही वेगळे प्रयत्...                2
# ..                                                ...              ...
# 57               after long time good movie is coming                4
# 58                           Kadak. 1st day 1st show.                5
# 59                          ALL THE BEST - TEAM ULTRA                5
# 60                                     movie to watch                5
# 61                                        👌🏻👌🏻👍🏻👍🏻👍🏻🤣                5
#
# [62 rows x 2 columns]

# %%
files = '/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/chapa_kata_comments.csv'
df_chapa_kata_trailer_comments.to_csv(files)

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML_project/datasets/chapa_kata_comments.csv')
df.head()
# Out:
#    Unnamed: 0                                            Comment  \
# 0           0         प्रदर्शित का नाही झाला वाट बघतोय राव आम्ही
# 1           1  <a href="https://youtu.be/Bb_mEMJ6yec?si=bU73D...
# 2           2  khup divasanni makarand siranni movie aanaliy ...
# 3           3                                        Sad trailer
# 4           4  मराठीत विनोदी चित्रपट पेक्षा काही वेगळे प्रयत्...
#
#    sentiment_score
# 0                1
# 1                3
# 2                3
# 3                1
# 4                2

# %%
df_chapa_kata_trailer_comments.head()
# Out:
#                                              Comment  sentiment_score
# 0         प्रदर्शित का नाही झाला वाट बघतोय राव आम्ही                1
# 1  <a href="https://youtu.be/Bb_mEMJ6yec?si=bU73D...                3
# 2  khup divasanni makarand siranni movie aanaliy ...                3
# 3                                        Sad trailer                1
# 4  मराठीत विनोदी चित्रपट पेक्षा काही वेगळे प्रयत्...                2

# %%
mean = df_chapa_kata_trailer_comments['sentiment_score'].mean()
mean
# Out:
# 3.7096774193548385
